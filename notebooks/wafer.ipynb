# %%
import os
import pandas as pd
from DataPreProcessing import PreProcessing

# %%
path=os.getcwd()

# %%
path
# Out:
# 'G:\\Projects\\Machine Learning\\WaferSensorFaultDetection\\notebooks'

# %%
os.chdir("G:\\Projects\\Machinelearning\\WaferSensorFaultDetection")
# Out:
#   Input In [13]
#     os.chdir(G:\\Projects\\Machine Learning\\WaferSensorFaultDetection)
#               ^
# SyntaxError: invalid syntax

# %%
preprocess=PreProcessing.PreProcessing()

# %%
df = pd.read_sql_query("select * from wafer", session)

# %%
df.head()
# Out:
#    index  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  \
# 0      0   3076.81   2158.75  2208.2334  1517.0152    1.0980     100.0
# 1      1   2951.62   2511.92  2253.5111  1397.5060    0.9660     100.0
# 2      2   2930.42   2505.17  2235.0556  1302.6607    1.6347     100.0
# 3      3   2997.28   2357.99  2141.0667  1236.5212    0.9698     100.0
# 4      4   3025.10   2475.18  2235.0556  1302.6607    1.6347     100.0
#
#    Sensor-7  Sensor-8  Sensor-9  ...  Sensor-582  Sensor-583  Sensor-584  \
# 0  110.1900    0.1247    1.4357  ...     64.2405      0.5016      0.0152
# 1  109.7611    0.1210    1.5527  ...      0.0000      0.4953      0.0105
# 2  109.9856    0.1230    1.4588  ...         NaN      0.4958      0.0111
# 3   98.3344    0.1238    1.5973  ...         NaN      0.4962      0.0086
# 4  109.9856    0.1230    1.5525  ...         NaN      0.4983      0.0159
#
#    Sensor-585  Sensor-586  Sensor-587  Sensor-588  Sensor-589  Sensor-590  \
# ...

# %%
df1=preprocess.KNNImputer(df)

# %%
features = df1.drop(['Good/Bad','index'], axis=1)
labels = df1['Good/Bad']

# %%
features
# Out:
#       Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  Sensor-7  \
# 0      3076.81   2158.75  2208.2334  1517.0152    1.0980     100.0  110.1900
# 1      2951.62   2511.92  2253.5111  1397.5060    0.9660     100.0  109.7611
# 2      2930.42   2505.17  2235.0556  1302.6607    1.6347     100.0  109.9856
# 3      2997.28   2357.99  2141.0667  1236.5212    0.9698     100.0   98.3344
# 4      3025.10   2475.18  2235.0556  1302.6607    1.6347     100.0  109.9856
# ...        ...       ...        ...        ...       ...       ...       ...
# 1532   3079.17   2405.56  2217.3777  1425.1041    1.7585     100.0  106.2556
# 1533   2911.37   2541.21  2207.8111  1202.4520    1.6219     100.0  108.7689
# 1534   3085.57   2364.78  2178.6889  1657.3518    1.6603     100.0  100.8022
# 1535   3053.49   2457.08  2172.5333  1351.9648    1.6377     100.0  103.8800
# 1536   3120.68   2396.40  2177.0222  1448.8499    1.5565     100.0  103.2567
#
# ...

# %%
df2=preprocess.zerovarcol(features)

# %%
df2.head()
# Out:
#    Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-7  Sensor-8  \
# 0   3076.81   2158.75  2208.2334  1517.0152    1.0980  110.1900    0.1247
# 1   2951.62   2511.92  2253.5111  1397.5060    0.9660  109.7611    0.1210
# 2   2930.42   2505.17  2235.0556  1302.6607    1.6347  109.9856    0.1230
# 3   2997.28   2357.99  2141.0667  1236.5212    0.9698   98.3344    0.1238
# 4   3025.10   2475.18  2235.0556  1302.6607    1.6347  109.9856    0.1230
#
#    Sensor-9  Sensor-10  Sensor-11  ...  Sensor-581  Sensor-582  Sensor-583  \
# 0    1.4357     0.0089     0.0052  ...     0.00900    64.24050      0.5016
# 1    1.5527     0.0119    -0.0082  ...     0.00810     0.00000      0.4953
# 2    1.4588    -0.0143     0.0017  ...     0.00680    73.02178      0.4958
# 3    1.5973    -0.0534    -0.0284  ...     0.00412    90.40428      0.4962
# 4    1.5525    -0.0078    -0.0005  ...     0.00570   111.00850      0.4983
#
# ...

# %%
# Out:
# 116
